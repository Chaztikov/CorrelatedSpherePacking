# %%
import os,sys
cwd=os.getcwd()
sys.path.append(cwd)
import numpy as np
import scipy
import scipy.stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import run_test_packing
from run_test_packing import *



def porosity_from_radii(radii_scaled, domain_volume,ndimensions = 3):
    pvolumes = radii_scaled**3 * 4 * np.pi / 3 if ndimensions==3 else radii_scaled**2 * np.pi 
    porosity = (domain_volume - pvolumes.sum()) / domain_volume
    return porosity,pvolumes

def compute_current_domain_bounding_box(radii_scaled,pts,bbox_vertices):
    radii_scaled.max()
#     idmax = pts.argmax(axis=0)
#     idmin = pts.argmin(axis=0)

#     bbox_vertices = np.vstack(
#         (pts.min(axis=0) + radii_scaled[idmin],
#         pts.max(axis=0) + radii_scaled[idmax] ))
#     bbox_vertices = np.vstack(
#         (pts.min(axis=0) ,
#         pts.max(axis=0) ))
#     print(pts.min(axis=0), pts.max(axis=0))

#     domain_volume = np.prod( bbox_vertices[1] - bbox_vertices[0] )
#     print(domain_volume)
    domain_volume= (xmax-xmin) * (ymax-ymin) * (zmax-zmin)
    porosity,pvolumes = porosity_from_radii(radii_scaled, domain_volume)
    return bbox_vertices, domain_volume, porosity,pvolumes

def compute_correction(x,r,xn,rn):
    dxn = (xn - x[None,:]) 
    dn = np.linalg.norm( dxn , 2 , axis=1)
    
    correct = (r+ rn)
    correct = correct[:,None] - dxn * 1./ dn[:,None]
    xnew = x + correct.sum(axis=0)
#     try( np.isnan(xnew.sum()) or np.isinf(xnew.sum() )):
#         ;
#     print(correct.sum(axis=0))
#     print(xnew)

    return xnew

def overlap_correction(x, r, pts, radii_scaled, RandomState, bbox_vertices, periodic=1,pnorm=2,deltar_min=1.005):
    reinit_flag=0

    if(pts.shape[0]<2):
        return x, 0   
    
    if(periodic):
#         kdt=PeriodicCKDTree(np.array(periodic_bounds), pts)
        icollide = PeriodicCKDTree(np.array(bbox_vertices[1]), pts).query_ball_point(x, deltar_min * np.max(r+radii_scaled))
    else:
        icollide = np.where(((x-pts[:])**2).sum(axis=1) < (radii_scaled[:] + r) * deltar_min  )[0]
        
#     print( " " , (icollide).sum() )
    
    if( (np.array(icollide)).sum() > 2 ):
        reinit_flag = 1
        
        if(periodic):
            x = compute_correction(x,r,pts[icollide],radii_scaled[icollide])
        else:
            x = compute_correction(x,r,pts[:],radii_scaled[:])
        
        xnew,reinit_flag = overlap_correction(x, r, pts, radii_scaled, RandomState, bbox_vertices, pnorm)
        #         if( np.isclose(0,(xnew-x).sum())):
        #             x = np.array([RandomState.uniform(bbox_vertices[0][i],bbox_vertices[1][i]) for i in range(3)])
            
    return x, reinit_flag

seed=0
xmax,xmin=1,0
ymax,ymin=1,0
zmax,zmin=1,0
ndimensions=3
radii_dist='lognormal'
radius_mu=0.001
radius_sig2=1e-10
tol_self_collision=1e-2
increment_print=int(1e1)
nsamples=int(1e3 * 4) #expect: far fewer used (until we achieve target porosity within tolerance)

percentilemin,percentilemax=10,90

target_porosity=0.35

'''
--------------------------------------------------------------------------------------------------------
--------------------------------------------------------------------------------------------------------
--------------------------------------------------------------------------------------------------------
'''



    
domain_volume= (xmax-xmin) * (ymax-ymin) * (zmax-zmin)
coord_min,coord_max,coord_minmax=np.min((xmin,ymin,zmin)), np.max((xmax,ymax,zmax)),np.min((xmax,ymax,zmax))
RandomState = np.random.RandomState(0)
print(radius_mu)
lognormal_sig2 = np.log( radius_sig2 / radius_mu**2 + 1 )
lognormal_mu = np.log( radius_mu ) - lognormal_sig2 / 2
radii = RandomState.lognormal( lognormal_mu, lognormal_sig2 ,nsamples)
radii.mean(),np.std(radii)

'''truncate sampled distribution'''
pmin = np.percentile(radii,percentilemin),
pmax = np.percentile(radii,percentilemax)
radii = radii[radii<pmax]
radii = radii[radii>pmin]
nsamplesclip = nsamples - radii.shape[0]
nsamples = radii.shape[0]# - nsamplesclip
# radii = np.sort(radii)

Z=None
pts=None
rmax=1
dmax=1
rscale=1
# if(do_rescale):
'''rescale radii to obtain desired porosity'''
rscale = ( (  np.sum( np.pi * (4./3.) * radii**3) ) / ( domain_volume * (1 - 0.9 * target_porosity) ) )**(1/3)
Z = radii/rscale
radius_mu_scaled = radius_mu / rscale
radius_sig2_scaled = radius_sig2 / rscale**2
rmax = ( Z ).max()
dmax = 2*rmax





# else:
#     domain_volume = np.ceil(( (radii**3 * 4 * np.pi/3.).sum() / (1.-target_porosity) ))
#     domain_length = np.ceil((domain_volume)**(1./3.)).astype(int)
#     sphere_length = np.ceil((domain_volume * target_porosity)**(1./3.)).astype(int)
#     xmax *= sphere_length
#     ymax *= sphere_length
#     zmax *= sphere_length
#     bbox_vertices = [(xmin,ymin,zmin),(xmax,ymax,zmax)]
#     Z = radii
#     bbox_vertices, domain_volume, porosity, pvolumes = compute_current_domain_bounding_box(radii, pts, bbox_vertices)
#     print("Current Porosity ", porosity)
'''plot original and transformed distributions'''
plt.hist(Z);
plt.title( "Transformed Lognormal Parameters: \n" + str( np.round( scipy.stats.lognorm.fit( np.atleast_2d(Z) ), 3) ))
plt.show()

plt.hist(radii);
plt.title( "Original Lognormal Parameters: \n" + str( np.round( scipy.stats.lognorm.fit( np.atleast_2d(radii) ), 3) ))
plt.show()


do_rescale=1
bbox_vertices = [(xmin,ymin,zmin),(xmax,ymax,zmax)]
periodic_bounds=bbox_vertices[1]

periodic_geometry=True
kdt=None
# if(periodic_geometry==True):
#     kdt = PeriodicCKDTree(periodic_bounds, pts)
# else:
#     kdt = scipy.spatial.KDTree(pts) #,leafsize=set_leafsize_factor * num_neighbors )
    

# approx_samples_per_dim = int((nsamples)**(2/3))
# print(approx_samples_per_dim)
# bbox_rescale_factor = 2*Z.max() * approx_samples_per_dim
# xmax *= bbox_rescale_factor
# ymax *= bbox_rescale_factor
# zmax *= bbox_rescale_factor

''' Detect Collisions and Translate Spheres '''
registered = []
unregistered = [i for i in range(nsamples)]
boundary = []
t_list = []
tlast = time.time()
radii_scaled = np.array([])
pts=np.array([])
rands=[]
for i,radius in enumerate(Z):
    
    r = radius
    pt=np.zeros([3])
#     pt = RandomState.uniform(0,1,[ndimensions])
#     rands.append(pt)
#     pt[0] = (pt[0] ) * (xmax-xmin) + xmin
#     pt[1] = (pt[1] ) * (ymax-ymin) + ymin
#     pt[2] = (pt[2] ) * (zmax-zmin) + zmin
    pt[0] = RandomState.uniform(0,xmax)
    pt[1] = RandomState.uniform(0,ymax)
    pt[2] = RandomState.uniform(0,zmax)
    
    x = pt.copy()
    
    if(i==0):
#         registered.append(i)
        pts = np.array([x.tolist()])
        radii_scaled = np.array([radius])
#         print(pts.shape, radii_scaled.shape)
        
    if(i>0 and i%increment_print==0):
#         print(pts.shape, radii_scaled.shape, len(registered))

#         try:
        bbox_vertices, domain_volume, current_porosity, pvolumes = compute_current_domain_bounding_box(radii_scaled, pts, bbox_vertices)
        print("\n Iteration",i,"\n Curr. Sph. Posn. ",x, "\n Sph. Rad.",r, 
              "\n time", time.time(), "\n current porosity" , current_porosity,
              "\n bbox_vertices", bbox_vertices, "\n domain_volume" , domain_volume)
#         except Exception as e:
#             print(e)
    else:
        if(pts.shape[0]>np.inf):
            break;
        else:
            x,reinit_flag = overlap_correction(x, r, pts, radii_scaled, RandomState, bbox_vertices)
#         reinit_flag=0
        if(reinit_flag==1):
            if(periodic_geometry==1):
                break;
                
        elif(reinit_flag==0):             
            
#             print(Z[i], r)
            registered.append(i)

            pts = np.vstack((pts,x))
            radii_scaled = np.hstack((radii_scaled,r))
            Z[i] = r
            try:
                unregistered.remove(i)
            except Exception as e:
                break;
    t_list.append(time.time() - tlast)
    tlast = time.time()
    

registered=np.array(registered)
domain_volume=xmax*ymax*zmax
bbox_vertices, domain_volume, porosity, pvolumes = compute_current_domain_bounding_box(radii_scaled, pts, bbox_vertices)
save_filename = 'packing'
#save packing output
idx_points = np.arange(0,len(registered)+1)






print("\n domain size ", " [xmin,xmax] ", xmin,xmax, " [ymin,ymax] ", ymin,ymax, " [zmin,zmax] ", zmin,zmax, " volume " , domain_volume)
print('particle volumes: sum, mean, median, min, max', pvolumes.sum(), pvolumes.mean(), np.median(pvolumes) , pvolumes.min(), pvolumes.max())
print("\n \n \n porosity ", porosity)
print("\n number of spheres ", registered.shape)
print("\n number of registered spheres ", registered.shape)
print("\n number of unregistered spheres ", registered.shape )
print("\n sphere distribution parameters ", radius_mu, radius_sig2)
print("\n mean coordination number ", )
print("\n \n \n ")

stacked_data = np.vstack((idx_points.astype(int), pts[:,0], pts[:,1], pts[:,2], radii_scaled[:])).T
np.savetxt(save_filename + ".txt", stacked_data, header="ID x y z r", fmt='%i,%E,%E,%E,%E')
'''
--------------------------------------------------------------------------------------------------------
--------------------------------------------------------------------------------------------------------
--------------------------------------------------------------------------------------------------------
'''
# Out:
# 0.001
#  Iteration 10
#  Curr. Sph. Posn.  [0.19087428 0.79139304 0.34216208]
#  Sph. Rad. 0.037111163853198036
#  time 1542662337.7226274
#  current porosity 0.9976451027970347
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 20
#  Curr. Sph. Posn.  [0.45194901 0.27708267 0.05560046]
#  Sph. Rad. 0.037110091722106005
#  time 1542662337.725696
#  current porosity 0.9957185086611083
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 30
#  Curr. Sph. Posn.  [0.0707839  0.47045535 0.04613702]
#  Sph. Rad. 0.03710762559212174
#  time 1542662337.7291546
#  current porosity 0.9937919291828862
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 40
#  Curr. Sph. Posn.  [0.4808295  0.17342971 0.36861677]
#  Sph. Rad. 0.0371111062174317
#  time 1542662337.7322795
#  current porosity 0.9918655646783063
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 50
#  Curr. Sph. Posn.  [0.19356411 0.93264093 0.23922315]
#  Sph. Rad. 0.03711123406044957
#  time 1542662337.7355483
#  current porosity 0.989939158030518
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 60
#  Curr. Sph. Posn.  [0.58012525 0.04517658 0.91808119]
#  Sph. Rad. 0.037107368830418805
#  time 1542662337.7388518
#  current porosity 0.9880126581315072
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 70
#  Curr. Sph. Posn.  [0.97187741 0.28581895 0.46227822]
#  Sph. Rad. 0.03710802067878577
#  time 1542662337.7429821
#  current porosity 0.9860860185905014
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 80
#  Curr. Sph. Posn.  [0.61753534 0.90646773 0.24778176]
#  Sph. Rad. 0.03711311412282394
#  time 1542662337.746691
#  current porosity 0.9841592627848713
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 90
#  Curr. Sph. Posn.  [0.72109255 0.93530041 0.90658632]
#  Sph. Rad. 0.03711179551888854
#  time 1542662337.7511895
#  current porosity 0.9822327446969767
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 100
#  Curr. Sph. Posn.  [0.34796249 0.61442608 0.62770854]
#  Sph. Rad. 0.03710665987546536
#  time 1542662337.7577717
#  current porosity 0.9803061456776366
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 110
#  Curr. Sph. Posn.  [0.73547147 0.20795986 0.1647649 ]
#  Sph. Rad. 0.03711114725965766
#  time 1542662337.7629654
#  current porosity 0.9783795909249443
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 120
#  Curr. Sph. Posn.  [0.17422156 0.26195517 0.20489878]
#  Sph. Rad. 0.03710915141149543
#  time 1542662337.7689338
#  current porosity 0.9764530206951468
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 130
#  Curr. Sph. Posn.  [0.92175654 0.72789532 0.09466832]
#  Sph. Rad. 0.0371126501098095
#  time 1542662337.77232
#  current porosity 0.9745266262627479
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 140
#  Curr. Sph. Posn.  [0.70795572 0.00272587 0.14552137]
#  Sph. Rad. 0.03710653559836303
#  time 1542662337.7754524
#  current porosity 0.9725999437616312
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 150
#  Curr. Sph. Posn.  [0.27617701 0.7566406  0.10332831]
#  Sph. Rad. 0.03710471956444215
#  time 1542662337.778726
#  current porosity 0.9706735752568552
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 160
#  Curr. Sph. Posn.  [0.86493745 0.75349542 0.9643692 ]
#  Sph. Rad. 0.03711359754794353
#  time 1542662337.7843986
#  current porosity 0.9687469698024662
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 170
#  Curr. Sph. Posn.  [0.12992487 0.98673446 0.46711171]
#  Sph. Rad. 0.037107786012160845
#  time 1542662337.789192
#  current porosity 0.9668202147007149
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 180
#  Curr. Sph. Posn.  [0.54475986 0.94620646 0.25917989]
#  Sph. Rad. 0.03710975149519953
#  time 1542662337.7926571
#  current porosity 0.964893783713806
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 190
#  Curr. Sph. Posn.  [0.44796037 0.7794772  0.85770466]
#  Sph. Rad. 0.03711109852416621
#  time 1542662337.796105
#  current porosity 0.9629672964050752
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 200
#  Curr. Sph. Posn.  [0.837154   0.74446307 0.4838964 ]
#  Sph. Rad. 0.03711145034426453
#  time 1542662337.7997177
#  current porosity 0.9610406958864778
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 210
#  Curr. Sph. Posn.  [0.47813796 0.36389277 0.80349747]
#  Sph. Rad. 0.0371073040280199
#  time 1542662337.8031843
#  current porosity 0.959114191623279
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 220
#  Curr. Sph. Posn.  [0.02483401 0.20956185 0.19471741]
#  Sph. Rad. 0.03710806603580115
#  time 1542662337.8075254
#  current porosity 0.957187568617063
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 230
#  Curr. Sph. Posn.  [0.77659224 0.24793679 0.24684592]
#  Sph. Rad. 0.03711207658616407
#  time 1542662337.8112724
#  current porosity 0.9552608823531155
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 240
#  Curr. Sph. Posn.  [0.64708837 0.50589605 0.95405972]
#  Sph. Rad. 0.037109078267444015
#  time 1542662337.8154004
#  current porosity 0.9533343356543638
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 250
#  Curr. Sph. Posn.  [0.86059879 0.90644496 0.53829992]
#  Sph. Rad. 0.03710808857251001
#  time 1542662337.8196256
#  current porosity 0.9514078105796085
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 260
#  Curr. Sph. Posn.  [0.36079542 0.27891121 0.00056962]
#  Sph. Rad. 0.03710522231778546
#  time 1542662337.8297658
#  current porosity 0.9494813946225643
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 270
#  Curr. Sph. Posn.  [0.75355875 0.38637757 0.56223816]
#  Sph. Rad. 0.03711119009404931
#  time 1542662337.8358977
#  current porosity 0.9475548453705214
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 280
#  Curr. Sph. Posn.  [0.14384705 0.78441326 0.2286723 ]
#  Sph. Rad. 0.03711166356407101
#  time 1542662337.8415477
#  current porosity 0.9456284517048061
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 290
#  Curr. Sph. Posn.  [0.26333281 0.77430645 0.64398412]
#  Sph. Rad. 0.037109530736881224
#  time 1542662337.8453133
#  current porosity 0.9437019948705454
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 300
#  Curr. Sph. Posn.  [0.55419319 0.31949224 0.51368922]
#  Sph. Rad. 0.037105831677503795
#  time 1542662337.850392
#  current porosity 0.9417754332097997
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 310
#  Curr. Sph. Posn.  [0.48497711 0.28147599 0.20617459]
#  Sph. Rad. 0.03710966009321165
#  time 1542662337.85602
#  current porosity 0.9398487366478568
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 320
#  Curr. Sph. Posn.  [0.74892985 0.35369243 0.88883289]
#  Sph. Rad. 0.037112680499714557
#  time 1542662337.8594716
#  current porosity 0.9379221493276781
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 330
#  Curr. Sph. Posn.  [0.47209406 0.65259162 0.12651426]
#  Sph. Rad. 0.03711248658135293
#  time 1542662337.863855
#  current porosity 0.9359955922549925
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 340
#  Curr. Sph. Posn.  [0.62117931 0.83995803 0.44904391]
#  Sph. Rad. 0.03710986538409104
#  time 1542662337.8680234
#  current porosity 0.9340688736624985
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 350
#  Curr. Sph. Posn.  [0.95254526 0.20448903 0.22038394]
#  Sph. Rad. 0.037109536383768946
#  time 1542662337.8719068
#  current porosity 0.9321421982180123
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 360
#  Curr. Sph. Posn.  [0.61878201 0.87288524 0.6587024 ]
#  Sph. Rad. 0.037105937467017874
#  time 1542662337.8765643
#  current porosity 0.9302155765467345
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 370
#  Curr. Sph. Posn.  [0.88792077 0.14298979 0.81625375]
#  Sph. Rad. 0.037109328966559815
#  time 1542662337.882837
#  current porosity 0.9282890169420852
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 380
#  Curr. Sph. Posn.  [0.22485568 0.79809155 0.05380057]
#  Sph. Rad. 0.03710849380920486
#  time 1542662337.8884935
#  current porosity 0.926362713090696
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 390
#  Curr. Sph. Posn.  [0.0044646  0.13322339 0.28346284]
#  Sph. Rad. 0.037112717774112604
#  time 1542662337.893878
#  current porosity 0.924436037194146
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 400
#  Curr. Sph. Posn.  [0.05858202 0.77756319 0.53870825]
#  Sph. Rad. 0.03710573922094943
#  time 1542662337.9001422
#  current porosity 0.9225095085725309
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 410
#  Curr. Sph. Posn.  [0.39273526 0.16432764 0.11573037]
#  Sph. Rad. 0.037107067510176804
#  time 1542662337.9066494
#  current porosity 0.9205829338045174
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 420
#  Curr. Sph. Posn.  [0.22187449 0.05449016 0.15319921]
#  Sph. Rad. 0.037112992939010166
#  time 1542662337.9117193
#  current porosity 0.9186563965810495
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 430
#  Curr. Sph. Posn.  [0.44741428 0.67812233 0.37414816]
#  Sph. Rad. 0.03710910899693442
#  time 1542662337.918049
#  current porosity 0.9167298138956967
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#  Iteration 440
#  Curr. Sph. Posn.  [0.34689564 0.5093795  0.34663208]
#  Sph. Rad. 0.037109874171738395
#  time 1542662337.9251463
#  current porosity 0.9148032515868254
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 450
#  Curr. Sph. Posn.  [0.39830332 0.75642378 0.73748399]
#  Sph. Rad. 0.037110833190175954
#  time 1542662337.935031
#  current porosity 0.9128767440384384
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 460
#  Curr. Sph. Posn.  [0.43250533 0.5247284  0.7724185 ]
#  Sph. Rad. 0.03710536718198718
#  time 1542662337.942331
#  current porosity 0.910950046538518
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 470
#  Curr. Sph. Posn.  [0.29338781 0.64345905 0.41800973]
#  Sph. Rad. 0.0371080607087487
#  time 1542662337.9495263
#  current porosity 0.9090235186039172
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 480
#  Curr. Sph. Posn.  [0.9937112  0.09783935 0.89488428]
#  Sph. Rad. 0.037108854047552556
#  time 1542662337.957148
#  current porosity 0.9070970162344425
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 490
#  Curr. Sph. Posn.  [0.72760401 0.63247417 0.14162976]
#  Sph. Rad. 0.03710902726510526
#  time 1542662337.9624932
#  current porosity 0.9051704204776964
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 500
#  Curr. Sph. Posn.  [0.34209539 0.30023524 0.20496922]
#  Sph. Rad. 0.03711019707911991
#  time 1542662337.968737
#  current porosity 0.9032438967951364
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 510
#  Curr. Sph. Posn.  [0.9298209  0.69428615 0.34008672]
#  Sph. Rad. 0.03711045371175348
#  time 1542662337.9793415
#  current porosity 0.9013174283280757
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 520
#  Curr. Sph. Posn.  [0.24210987 0.32257447 0.0787384 ]
#  Sph. Rad. 0.037110581394722154
#  time 1542662337.9864702
#  current porosity 0.8993908740238972
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 530
#  Curr. Sph. Posn.  [0.10409745 0.82525654 0.00982266]
#  Sph. Rad. 0.03711119586318136
#  time 1542662337.9962094
#  current porosity 0.8974644268547666
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 540
#  Curr. Sph. Posn.  [0.69021493 0.7316708  0.87828879]
#  Sph. Rad. 0.03711097533728137
#  time 1542662338.0028493
#  current porosity 0.895537898722806
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 550
#  Curr. Sph. Posn.  [0.50979696 0.67150508 0.04344593]
#  Sph. Rad. 0.03711074345729967
#  time 1542662338.0132189
#  current porosity 0.8936111943813448
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 560
#  Curr. Sph. Posn.  [0.92373807 0.12328678 0.06189334]
#  Sph. Rad. 0.03711357891332174
#  time 1542662338.022171
#  current porosity 0.891684637124903
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 570
#  Curr. Sph. Posn.  [0.68782805 0.4377935  0.39680588]
#  Sph. Rad. 0.037106536593795654
#  time 1542662338.0306795
#  current porosity 0.8897580421714478
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 580
#  Curr. Sph. Posn.  [0.55940968 0.21787992 0.99288717]
#  Sph. Rad. 0.03711413069827374
#  time 1542662338.0458083
#  current porosity 0.8878316493901297
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 590
#  Curr. Sph. Posn.  [0.13438719 0.97522724 0.09123636]
#  Sph. Rad. 0.037105850680935186
#  time 1542662338.058697
#  current porosity 0.8859052175331513
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 600
#  Curr. Sph. Posn.  [0.78508887 0.00629245 0.28106435]
#  Sph. Rad. 0.037111179929145685
#  time 1542662338.0681539
#  current porosity 0.8839786924738602
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 610
#  Curr. Sph. Posn.  [0.99211713 0.1794204  0.79541246]
#  Sph. Rad. 0.037112188531413855
#  time 1542662338.0793538
#  current porosity 0.8820520245229835
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 620
#  Curr. Sph. Posn.  [0.06799168 0.57512418 0.17801496]
#  Sph. Rad. 0.037109299343637714
#  time 1542662338.0952196
#  current porosity 0.8801256352720704
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 630
#  Curr. Sph. Posn.  [0.45800456 0.39377652 0.21103162]
#  Sph. Rad. 0.03710670456902361
#  time 1542662338.1045282
#  current porosity 0.8781989087205871
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 640
#  Curr. Sph. Posn.  [0.44724589 0.47984029 0.63590841]
#  Sph. Rad. 0.03710930348866064
#  time 1542662338.1174495
#  current porosity 0.8762725970295852
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 650
#  Curr. Sph. Posn.  [0.34412074 0.39912734 0.3676832 ]
#  Sph. Rad. 0.0371070753218466
#  time 1542662338.1290169
#  current porosity 0.8743458605380338
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 660
#  Curr. Sph. Posn.  [0.19777003 0.24534088 0.74279645]
#  Sph. Rad. 0.037110730045552986
#  time 1542662338.139886
#  current porosity 0.8724194813406603
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 670
#  Curr. Sph. Posn.  [0.38689301 0.49901266 0.89511405]
#  Sph. Rad. 0.037108308280430685
#  time 1542662338.1479287
#  current porosity 0.8704928260870987
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 680
#  Curr. Sph. Posn.  [0.42640106 0.12583076 0.10684191]
#  Sph. Rad. 0.03710673492271638
#  time 1542662338.1652849
#  current porosity 0.8685661143034887
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 690
#  Curr. Sph. Posn.  [0.94994547 0.62122912 0.35815414]
#  Sph. Rad. 0.037110156873059595
#  time 1542662338.1732628
#  current porosity 0.8666397078030372
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 700
#  Curr. Sph. Posn.  [0.70075092 0.46207227 0.03329528]
#  Sph. Rad. 0.03710862120669228
#  time 1542662338.1841526
#  current porosity 0.86471307391966
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 710
#  Curr. Sph. Posn.  [0.57547125 0.15775161 0.07167158]
#  Sph. Rad. 0.03710668882302201
#  time 1542662338.1958308
#  current porosity 0.8627867115686165
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 720
#  Curr. Sph. Posn.  [0.58303379 0.8426515  0.77031265]
#  Sph. Rad. 0.03710633842593597
#  time 1542662338.2058098
#  current porosity 0.8608601591041813
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 730
#  Curr. Sph. Posn.  [0.51195605 0.83093056 0.20681226]
#  Sph. Rad. 0.037113340656424354
#  time 1542662338.2128496
#  current porosity 0.8589337682800616
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 740
#  Curr. Sph. Posn.  [0.39328895 0.47708726 0.6593618 ]
#  Sph. Rad. 0.03710849098052712
#  time 1542662338.222885
#  current porosity 0.8570072799946837
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 750
#  Curr. Sph. Posn.  [0.95692361 0.43061617 0.63438624]
#  Sph. Rad. 0.037110874348117814
#  time 1542662338.2333992
#  current porosity 0.8550809138406494
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 760
#  Curr. Sph. Posn.  [0.9251364  0.81479716 0.96227757]
#  Sph. Rad. 0.0371114795819683
#  time 1542662338.242286
#  current porosity 0.8531543199455909
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 770
#  Curr. Sph. Posn.  [0.9716191  0.12318852 0.396784  ]
#  Sph. Rad. 0.03710923916123245
#  time 1542662338.2549813
#  current porosity 0.8512277253398544
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 780
#  Curr. Sph. Posn.  [0.79956393 0.14154897 0.76264279]
#  Sph. Rad. 0.037108983957825366
#  time 1542662338.2653072
#  current porosity 0.8493011159895607
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 790
#  Curr. Sph. Posn.  [0.42910066 0.01722348 0.98784477]
#  Sph. Rad. 0.037108392034299505
#  time 1542662338.2762184
#  current porosity 0.8473745136541313
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 800
#  Curr. Sph. Posn.  [0.27879951 0.11069951 0.34169521]
#  Sph. Rad. 0.037108187890198804
#  time 1542662338.291874
#  current porosity 0.8454479651513278
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 810
#  Curr. Sph. Posn.  [0.41330761 0.39596733 0.75701802]
#  Sph. Rad. 0.0371058049376496
#  time 1542662338.305901
#  current porosity 0.8435212381683626
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 820
#  Curr. Sph. Posn.  [0.99142331 0.57037672 0.45900402]
#  Sph. Rad. 0.037105444414027994
#  time 1542662338.3236861
#  current porosity 0.8415946390537545
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#  Iteration 830
#  Curr. Sph. Posn.  [0.41791321 0.04958951 0.41214765]
#  Sph. Rad. 0.037112314735472426
#  time 1542662338.3405786
#  current porosity 0.8396683047801419
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 840
#  Curr. Sph. Posn.  [0.58812976 0.13720967 0.16496779]
#  Sph. Rad. 0.037107293229449015
#  time 1542662338.3517168
#  current porosity 0.83774133320723
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 850
#  Curr. Sph. Posn.  [0.8210121  0.11794768 0.00167499]
#  Sph. Rad. 0.03711029545449823
#  time 1542662338.3658829
#  current porosity 0.8358149018728844
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 860
#  Curr. Sph. Posn.  [0.12291964 0.74718681 0.77741356]
#  Sph. Rad. 0.03710568935119211
#  time 1542662338.3856459
#  current porosity 0.8338883119276908
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 870
#  Curr. Sph. Posn.  [0.13383653 0.20875951 0.42301876]
#  Sph. Rad. 0.03711173179045474
#  time 1542662338.397696
#  current porosity 0.8319617786799665
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 880
#  Curr. Sph. Posn.  [0.85566478 0.98739767 0.66744421]
#  Sph. Rad. 0.0371067956914206
#  time 1542662338.4157372
#  current porosity 0.8300354858089674
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 890
#  Curr. Sph. Posn.  [0.67863544 0.95395951 0.15102331]
#  Sph. Rad. 0.03710837499118226
#  time 1542662338.434213
#  current porosity 0.8281089643663713
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 900
#  Curr. Sph. Posn.  [0.76015948 0.23417581 0.1751864 ]
#  Sph. Rad. 0.03711361580275997
#  time 1542662338.4464872
#  current porosity 0.8261822108938378
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 910
#  Curr. Sph. Posn.  [0.46372049 0.0396175  0.94476717]
#  Sph. Rad. 0.037112576609144875
#  time 1542662338.467932
#  current porosity 0.8242556843968303
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 920
#  Curr. Sph. Posn.  [0.29917027 0.1750788  0.18531824]
#  Sph. Rad. 0.03710852088889496
#  time 1542662338.4961336
#  current porosity 0.822329175538968
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 930
#  Curr. Sph. Posn.  [0.50813145 0.66072791 0.49932947]
#  Sph. Rad. 0.03711062619599575
#  time 1542662338.5138628
#  current porosity 0.8204024849945446
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 940
#  Curr. Sph. Posn.  [0.06476037 0.36095286 0.12784881]
#  Sph. Rad. 0.03710522357179903
#  time 1542662338.5419862
#  current porosity 0.8184756939799056
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 950
#  Curr. Sph. Posn.  [6.28062185e-01 3.06537211e-04 1.68776573e-02]
#  Sph. Rad. 0.03710819933878223
#  time 1542662338.5692544
#  current porosity 0.816549031684267
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 960
#  Curr. Sph. Posn.  [0.34900304 0.6638403  0.3220158 ]
#  Sph. Rad. 0.03711336718149536
#  time 1542662338.595121
#  current porosity 0.81462233394807
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 970
#  Curr. Sph. Posn.  [0.99662904 0.56821748 0.22949735]
#  Sph. Rad. 0.037111804350841125
#  time 1542662338.6330764
#  current porosity 0.8126959206147175
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 980
#  Curr. Sph. Posn.  [0.94130089 0.80182819 0.5391446 ]
#  Sph. Rad. 0.03710765988719942
#  time 1542662338.6491446
#  current porosity 0.8107692273753844
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 990
#  Curr. Sph. Posn.  [0.3165721  0.95928769 0.43937881]
#  Sph. Rad. 0.03711337278820396
#  time 1542662338.6622746
#  current porosity 0.8088426610430005
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1000
#  Curr. Sph. Posn.  [0.3285802  0.07007694 0.25880761]
#  Sph. Rad. 0.03711113024971389
#  time 1542662338.6866083
#  current porosity 0.8069160677668674
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1010
#  Curr. Sph. Posn.  [0.7305207  0.78416684 0.40177979]
#  Sph. Rad. 0.037104829700739694
#  time 1542662338.717849
#  current porosity 0.8049893979866285
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1020
#  Curr. Sph. Posn.  [0.85937422 0.01534488 0.71960635]
#  Sph. Rad. 0.03711154837197044
#  time 1542662338.752594
#  current porosity 0.8030627950682662
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1030
#  Curr. Sph. Posn.  [0.48017993 0.06209095 0.83505378]
#  Sph. Rad. 0.037107521951446204
#  time 1542662338.7856588
#  current porosity 0.8011362717254318
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1040
#  Curr. Sph. Posn.  [0.02875162 0.24404658 0.45283105]
#  Sph. Rad. 0.03710783821586796
#  time 1542662338.8080006
#  current porosity 0.7992097522114595
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1050
#  Curr. Sph. Posn.  [0.97197972 0.01816509 0.14665418]
#  Sph. Rad. 0.037108566957093775
#  time 1542662338.8261144
#  current porosity 0.7972832655053035
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1060
#  Curr. Sph. Posn.  [0.4144471  0.93821627 0.56709034]
#  Sph. Rad. 0.03710807642250895
#  time 1542662338.8388503
#  current porosity 0.7953569583501242
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1070
#  Curr. Sph. Posn.  [0.4355621  0.70154286 0.33870941]
#  Sph. Rad. 0.037110013666856935
#  time 1542662338.8537488
#  current porosity 0.7934303469538266
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1080
#  Curr. Sph. Posn.  [0.74324501 0.55676608 0.46526024]
#  Sph. Rad. 0.03711129952976589
#  time 1542662338.8907356
#  current porosity 0.7915039925113703
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1090
#  Curr. Sph. Posn.  [0.54347256 0.82006768 0.26848358]
#  Sph. Rad. 0.03711043244629472
#  time 1542662338.9132571
#  current porosity 0.7895775236338821
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1100
#  Curr. Sph. Posn.  [0.47821614 0.18414942 0.16143147]
#  Sph. Rad. 0.03711041909534147
#  time 1542662338.9368117
#  current porosity 0.7876509196426469
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1110
#  Curr. Sph. Posn.  [0.26935275 0.69492682 0.70992859]
#  Sph. Rad. 0.03711096060880407
#  time 1542662338.9963992
#  current porosity 0.7857241679927427
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1120
#  Curr. Sph. Posn.  [0.76490868 0.7221116  0.11774831]
#  Sph. Rad. 0.03710937102994563
#  time 1542662339.0302722
#  current porosity 0.7837974301401782
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1130
#  Curr. Sph. Posn.  [0.11677321 0.8019301  0.84872924]
#  Sph. Rad. 0.03711214663959749
#  time 1542662339.0527616
#  current porosity 0.7818708531622938
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1140
#  Curr. Sph. Posn.  [0.36971966 0.92156548 0.01968476]
#  Sph. Rad. 0.037109005258559445
#  time 1542662339.0983565
#  current porosity 0.7799445094058026
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1150
#  Curr. Sph. Posn.  [0.56750956 0.78979116 0.19976441]
#  Sph. Rad. 0.03711299058277432
#  time 1542662339.139741
#  current porosity 0.7780178697863592
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1160
#  Curr. Sph. Posn.  [0.83990615 0.1754583  0.67734155]
#  Sph. Rad. 0.03711217352089317
#  time 1542662339.1697707
#  current porosity 0.7760911327441793
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1170
#  Curr. Sph. Posn.  [0.58231293 0.77079135 0.68957864]
#  Sph. Rad. 0.037105812872778046
#  time 1542662339.220635
#  current porosity 0.7741644612038405
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1180
#  Curr. Sph. Posn.  [0.80478534 0.71791304 0.14440926]
#  Sph. Rad. 0.03711076364077885
#  time 1542662339.2664464
#  current porosity 0.7722379495563396
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1190
#  Curr. Sph. Posn.  [0.0461697  0.77171261 0.71336406]
#  Sph. Rad. 0.03711005964954654
#  time 1542662339.3040147
#  current porosity 0.7703113409202148
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1200
#  Curr. Sph. Posn.  [0.86777293 0.3006845  0.74212132]
#  Sph. Rad. 0.03710677037108038
#  time 1542662339.349836
#  current porosity 0.7683847982706724
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1210
#  Curr. Sph. Posn.  [0.01432295 0.00993839 0.94243449]
#  Sph. Rad. 0.037107328821876076
#  time 1542662339.377295
#  current porosity 0.7664583172090089
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1220
#  Curr. Sph. Posn.  [0.77121156 0.26595899 0.91791636]
#  Sph. Rad. 0.03710990723789651
#  time 1542662339.401605
#  current porosity 0.7645317253850092
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#  Iteration 1230
#  Curr. Sph. Posn.  [0.06334503 0.16051198 0.90034969]
#  Sph. Rad. 0.03710501634807849
#  time 1542662339.4630113
#  current porosity 0.7626051321235896
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1240
#  Curr. Sph. Posn.  [0.76066666 0.38627737 0.8412092 ]
#  Sph. Rad. 0.03711303993309686
#  time 1542662339.512508
#  current porosity 0.7606785925237256
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1250
#  Curr. Sph. Posn.  [0.55122756 0.03132319 0.75399653]
#  Sph. Rad. 0.03710929303172693
#  time 1542662339.5643525
#  current porosity 0.7587518678613601
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1260
#  Curr. Sph. Posn.  [0.25145586 0.15060629 0.58184057]
#  Sph. Rad. 0.037109810347366545
#  time 1542662339.5803106
#  current porosity 0.7568253581439712
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1270
#  Curr. Sph. Posn.  [0.05565251 0.36267749 0.93946924]
#  Sph. Rad. 0.03711183030664984
#  time 1542662339.6243365
#  current porosity 0.7548987966095975
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1280
#  Curr. Sph. Posn.  [0.68774854 0.3023215  0.78339475]
#  Sph. Rad. 0.03711041180628815
#  time 1542662339.65855
#  current porosity 0.7529721596178951
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1290
#  Curr. Sph. Posn.  [0.35997977 0.12067744 0.83523191]
#  Sph. Rad. 0.03711149082997349
#  time 1542662339.6981437
#  current porosity 0.7510455774307316
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1300
#  Curr. Sph. Posn.  [0.87597799 0.88826896 0.96629709]
#  Sph. Rad. 0.03710683051109723
#  time 1542662339.721482
#  current porosity 0.7491190059674757
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1310
#  Curr. Sph. Posn.  [0.11210405 0.47097228 0.86104389]
#  Sph. Rad. 0.037110327173304224
#  time 1542662339.7711604
#  current porosity 0.7471925160572139
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1320
#  Curr. Sph. Posn.  [0.3760084  0.03379432 0.23682702]
#  Sph. Rad. 0.03711101553793504
#  time 1542662339.8233736
#  current porosity 0.7452661152203256
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1330
#  Curr. Sph. Posn.  [0.94204081 0.27290795 0.96574234]
#  Sph. Rad. 0.037106136945171043
#  time 1542662339.8608174
#  current porosity 0.7433393602513975
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1340
#  Curr. Sph. Posn.  [0.17716864 0.86559775 0.3690736 ]
#  Sph. Rad. 0.037105965124097445
#  time 1542662339.9512408
#  current porosity 0.7414127197775144
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1350
#  Curr. Sph. Posn.  [0.00812305 0.65418579 0.28642516]
#  Sph. Rad. 0.03710983652747758
#  time 1542662339.9975533
#  current porosity 0.7394859218874922
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1360
#  Curr. Sph. Posn.  [0.58953911 0.00465019 0.78792732]
#  Sph. Rad. 0.037110152194180505
#  time 1542662340.042712
#  current porosity 0.7375591775591503
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1370
#  Curr. Sph. Posn.  [0.23201727 0.89868513 0.68636824]
#  Sph. Rad. 0.037112111165444064
#  time 1542662340.1108375
#  current porosity 0.7356326282966538
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1380
#  Curr. Sph. Posn.  [0.44306433 0.44978198 0.02096677]
#  Sph. Rad. 0.037106401195127814
#  time 1542662340.1542344
#  current porosity 0.733706273375332
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1390
#  Curr. Sph. Posn.  [0.53703323 0.78907387 0.50123403]
#  Sph. Rad. 0.03711083670002712
#  time 1542662340.1814759
#  current porosity 0.7317798099573622
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1400
#  Curr. Sph. Posn.  [0.92226842 0.48265854 0.74213317]
#  Sph. Rad. 0.0371129834284844
#  time 1542662340.2603705
#  current porosity 0.7298532743912456
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1410
#  Curr. Sph. Posn.  [0.86235418 0.96878632 0.95362624]
#  Sph. Rad. 0.03711323263525379
#  time 1542662340.2783368
#  current porosity 0.7279267181403397
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1420
#  Curr. Sph. Posn.  [0.88886796 0.89540422 0.42999159]
#  Sph. Rad. 0.03711100304945703
#  time 1542662340.304652
#  current porosity 0.7260000289192419
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1430
#  Curr. Sph. Posn.  [0.74404481 0.44134778 0.46237761]
#  Sph. Rad. 0.03711177652963058
#  time 1542662340.3318813
#  current porosity 0.7240734678742874
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1440
#  Curr. Sph. Posn.  [0.45918087 0.71706995 0.33523642]
#  Sph. Rad. 0.037107925964979346
#  time 1542662340.4021225
#  current porosity 0.722146955993999
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1450
#  Curr. Sph. Posn.  [0.87120955 0.76373    0.25899665]
#  Sph. Rad. 0.03710469177469465
#  time 1542662340.461645
#  current porosity 0.7202204979591027
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1460
#  Curr. Sph. Posn.  [0.42028056 0.20536176 0.80420082]
#  Sph. Rad. 0.03710914934912072
#  time 1542662340.542509
#  current porosity 0.718294052058808
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1470
#  Curr. Sph. Posn.  [0.50372833 0.45753631 0.75113835]
#  Sph. Rad. 0.037111323987977174
#  time 1542662340.596473
#  current porosity 0.7163676285601015
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1480
#  Curr. Sph. Posn.  [0.41881723 0.01937738 0.30051182]
#  Sph. Rad. 0.03710961976291205
#  time 1542662340.6696072
#  current porosity 0.7144410355194655
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1490
#  Curr. Sph. Posn.  [0.23776663 0.14992559 0.82093714]
#  Sph. Rad. 0.03710843677289915
#  time 1542662340.7645879
#  current porosity 0.7125146452408444
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1500
#  Curr. Sph. Posn.  [0.30086231 0.88243239 0.17693005]
#  Sph. Rad. 0.03710945819105267
#  time 1542662340.8214293
#  current porosity 0.7105881668008546
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1510
#  Curr. Sph. Posn.  [0.26762549 0.91519105 0.47704561]
#  Sph. Rad. 0.03711242082482978
#  time 1542662340.886406
#  current porosity 0.7086615711024751
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1520
#  Curr. Sph. Posn.  [0.18751932 0.52351554 0.14924499]
#  Sph. Rad. 0.03710496155192868
#  time 1542662340.952913
#  current porosity 0.7067349268372631
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1530
#  Curr. Sph. Posn.  [0.41131225 0.55949927 0.1044667 ]
#  Sph. Rad. 0.03711122219528171
#  time 1542662341.0412328
#  current porosity 0.7048083889734634
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1540
#  Curr. Sph. Posn.  [0.55384584 0.93125463 0.92112219]
#  Sph. Rad. 0.03710556982831854
#  time 1542662341.1201503
#  current porosity 0.7028816075980845
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1550
#  Curr. Sph. Posn.  [0.89739362 0.05698035 0.67306465]
#  Sph. Rad. 0.037111209459835336
#  time 1542662341.202174
#  current porosity 0.7009549240342543
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1560
#  Curr. Sph. Posn.  [0.85928335 0.83168703 0.95061979]
#  Sph. Rad. 0.03710709263641843
#  time 1542662341.2972069
#  current porosity 0.6990285947287825
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1570
#  Curr. Sph. Posn.  [0.92863675 0.56401702 0.6018799 ]
#  Sph. Rad. 0.03710963009538276
#  time 1542662341.3863332
#  current porosity 0.6971018647452909
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1580
#  Curr. Sph. Posn.  [0.40884269 0.5736796  0.73729114]
#  Sph. Rad. 0.03710541982425933
#  time 1542662341.4373667
#  current porosity 0.6951753080096273
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1590
#  Curr. Sph. Posn.  [0.55915756 0.55094644 0.51937594]
#  Sph. Rad. 0.0371067711166583
#  time 1542662341.5133429
#  current porosity 0.6932489356169644
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#  Iteration 1600
#  Curr. Sph. Posn.  [0.00619771 0.91980676 0.69710349]
#  Sph. Rad. 0.03710665665392889
#  time 1542662341.6148696
#  current porosity 0.6913225296461056
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1610
#  Curr. Sph. Posn.  [0.54886085 0.46375405 0.41543401]
#  Sph. Rad. 0.03711214724932794
#  time 1542662341.7048748
#  current porosity 0.6893958510639642
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1620
#  Curr. Sph. Posn.  [0.73884458 0.71191156 0.92747451]
#  Sph. Rad. 0.037109614139179695
#  time 1542662341.837932
#  current porosity 0.6874690979065694
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1630
#  Curr. Sph. Posn.  [0.12615389 0.86439266 0.86406747]
#  Sph. Rad. 0.037110038748197946
#  time 1542662342.0029297
#  current porosity 0.685542399402556
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1640
#  Curr. Sph. Posn.  [0.22404063 0.3767429  0.69770858]
#  Sph. Rad. 0.037109837550476456
#  time 1542662342.0802753
#  current porosity 0.6836158152432241
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1650
#  Curr. Sph. Posn.  [0.48819666 0.37202476 0.19617209]
#  Sph. Rad. 0.0371079945495765
#  time 1542662342.1679852
#  current porosity 0.6816892988136475
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1660
#  Curr. Sph. Posn.  [0.02753244 0.27992568 0.8117664 ]
#  Sph. Rad. 0.037109979737393176
#  time 1542662342.3310976
#  current porosity 0.6797625307624373
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1670
#  Curr. Sph. Posn.  [0.40364022 0.54477873 0.04017637]
#  Sph. Rad. 0.037106010717287995
#  time 1542662342.4219217
#  current porosity 0.6778360334529486
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1680
#  Curr. Sph. Posn.  [0.54543245 0.29310578 0.12380606]
#  Sph. Rad. 0.03710928051184601
#  time 1542662342.5405827
#  current porosity 0.6759094380865225
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1690
#  Curr. Sph. Posn.  [0.71009303 0.90579841 0.43470673]
#  Sph. Rad. 0.037109971431841124
#  time 1542662342.710468
#  current porosity 0.6739830098793673
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1700
#  Curr. Sph. Posn.  [0.24449777 0.2523659  0.41617989]
#  Sph. Rad. 0.03710766804323696
#  time 1542662342.7960742
#  current porosity 0.6720564753885343
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1710
#  Curr. Sph. Posn.  [0.5966702  0.87089198 0.69840843]
#  Sph. Rad. 0.03711016494662607
#  time 1542662342.9319153
#  current porosity 0.6701299798918906
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1720
#  Curr. Sph. Posn.  [0.27378431 0.23075059 0.27093728]
#  Sph. Rad. 0.03710990573749099
#  time 1542662343.0241804
#  current porosity 0.6682035589764227
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1730
#  Curr. Sph. Posn.  [0.0888201  0.42631844 0.75095622]
#  Sph. Rad. 0.03711352433256557
#  time 1542662343.1490948
#  current porosity 0.6662770502023012
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1740
#  Curr. Sph. Posn.  [0.01481572 0.74357013 0.41539948]
#  Sph. Rad. 0.03710567405227865
#  time 1542662343.3046029
#  current porosity 0.6643506345618108
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1750
#  Curr. Sph. Posn.  [0.03881181 0.24667046 0.10123266]
#  Sph. Rad. 0.03710762580380572
#  time 1542662343.3971965
#  current porosity 0.6624241147899095
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1760
#  Curr. Sph. Posn.  [0.07816848 0.25290603 0.7107665 ]
#  Sph. Rad. 0.0371066327445619
#  time 1542662343.4864757
#  current porosity 0.6604974400089054
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1770
#  Curr. Sph. Posn.  [0.23432595 0.89661154 0.03187045]
#  Sph. Rad. 0.03711162102406394
#  time 1542662343.5504787
#  current porosity 0.6585710825348183
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1780
#  Curr. Sph. Posn.  [0.15914371 0.49335937 0.38655678]
#  Sph. Rad. 0.03710734832736277
#  time 1542662343.6307595
#  current porosity 0.6566444823688815
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1790
#  Curr. Sph. Posn.  [0.18132699 0.34230412 0.46068286]
#  Sph. Rad. 0.037113836890393874
#  time 1542662343.8243058
#  current porosity 0.6547178287607569
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1800
#  Curr. Sph. Posn.  [0.109475   0.73602747 0.3250595 ]
#  Sph. Rad. 0.03711158356514428
#  time 1542662343.9734979
#  current porosity 0.6527912501350821
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1810
#  Curr. Sph. Posn.  [0.07464924 0.11973123 0.99271727]
#  Sph. Rad. 0.037111359612610945
#  time 1542662344.2994432
#  current porosity 0.650864619116442
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1820
#  Curr. Sph. Posn.  [0.6416878  0.49670186 0.02509595]
#  Sph. Rad. 0.0371060535872951
#  time 1542662344.4433627
#  current porosity 0.6489381185170795
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1830
#  Curr. Sph. Posn.  [0.79285329 0.24863459 0.86368439]
#  Sph. Rad. 0.03710743513306474
#  time 1542662344.5987034
#  current porosity 0.6470114259827952
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1840
#  Curr. Sph. Posn.  [0.74087065 0.23605216 0.79804322]
#  Sph. Rad. 0.037112362975328834
#  time 1542662344.6947978
#  current porosity 0.6450850018272984
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1850
#  Curr. Sph. Posn.  [0.26131814 0.63216148 0.91088096]
#  Sph. Rad. 0.03710908547220387
#  time 1542662344.8454278
#  current porosity 0.6431585198627623
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1860
#  Curr. Sph. Posn.  [4.55517322e-01 2.06948482e-04 8.62196460e-01]
#  Sph. Rad. 0.037104994768835144
#  time 1542662345.0632186
#  current porosity 0.6412317969822999
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1870
#  Curr. Sph. Posn.  [0.06357574 0.74638623 0.88131006]
#  Sph. Rad. 0.03711132901729187
#  time 1542662345.2079074
#  current porosity 0.6393052624516051
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1880
#  Curr. Sph. Posn.  [0.4195658  0.38734119 0.06416409]
#  Sph. Rad. 0.03711103104447772
#  time 1542662345.3576033
#  current porosity 0.6373786125728458
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1890
#  Curr. Sph. Posn.  [0.90656012 0.31293597 0.78789289]
#  Sph. Rad. 0.03711102754019069
#  time 1542662345.5249767
#  current porosity 0.6354522712162326
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1900
#  Curr. Sph. Posn.  [0.44020982 0.36165973 0.1821511 ]
#  Sph. Rad. 0.037108565936552415
#  time 1542662345.722299
#  current porosity 0.6335258034064737
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1910
#  Curr. Sph. Posn.  [0.81433557 0.601774   0.03301348]
#  Sph. Rad. 0.0371073017902893
#  time 1542662345.8280747
#  current porosity 0.631599137839771
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1920
#  Curr. Sph. Posn.  [0.53764486 0.26758453 0.16852336]
#  Sph. Rad. 0.03711200141642936
#  time 1542662345.8878293
#  current porosity 0.6296724638138343
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1930
#  Curr. Sph. Posn.  [0.51115833 0.99081748 0.8375544 ]
#  Sph. Rad. 0.03711141879130669
#  time 1542662346.0037258
#  current porosity 0.6277458156093076
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1940
#  Curr. Sph. Posn.  [0.19884891 0.87949015 0.27108715]
#  Sph. Rad. 0.03710993187861536
#  time 1542662346.1019819
#  current porosity 0.6258193474344549
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1950
#  Curr. Sph. Posn.  [0.20093199 0.50801393 0.82913876]
#  Sph. Rad. 0.03711223146012166
#  time 1542662346.350728
#  current porosity 0.6238928513344686
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1960
#  Curr. Sph. Posn.  [0.94072305 0.02051245 0.12155266]
#  Sph. Rad. 0.03710748297634628
#  time 1542662346.575808
#  current porosity 0.621966179935159
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#  Iteration 1970
#  Curr. Sph. Posn.  [0.83277915 0.66708208 0.97577876]
#  Sph. Rad. 0.03711312367372564
#  time 1542662346.7909522
#  current porosity 0.620039663662747
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1980
#  Curr. Sph. Posn.  [0.11974357 0.2547367  0.82842141]
#  Sph. Rad. 0.03710622588711204
#  time 1542662347.012123
#  current porosity 0.6181133257011491
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 1990
#  Curr. Sph. Posn.  [0.96679304 0.42879515 0.09930772]
#  Sph. Rad. 0.03711003926306872
#  time 1542662347.2865212
#  current porosity 0.6161867121440459
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2000
#  Curr. Sph. Posn.  [0.39973934 0.15672587 0.15948778]
#  Sph. Rad. 0.03710881879352354
#  time 1542662347.4082396
#  current porosity 0.6142599795904324
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2010
#  Curr. Sph. Posn.  [0.8228943  0.760627   0.70883249]
#  Sph. Rad. 0.037106075676589245
#  time 1542662347.5903955
#  current porosity 0.6123334844356978
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2020
#  Curr. Sph. Posn.  [0.32213346 0.91074591 0.17146522]
#  Sph. Rad. 0.03710935124644373
#  time 1542662347.8847644
#  current porosity 0.6104067959495518
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2030
#  Curr. Sph. Posn.  [0.6833749  0.51577525 0.69866538]
#  Sph. Rad. 0.03710882398410509
#  time 1542662348.255936
#  current porosity 0.6084802562993425
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2040
#  Curr. Sph. Posn.  [0.88894006 0.62976939 0.70831202]
#  Sph. Rad. 0.03710998641418618
#  time 1542662348.4843266
#  current porosity 0.6065535848999218
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2050
#  Curr. Sph. Posn.  [0.10218344 0.87778074 0.65887353]
#  Sph. Rad. 0.03710472273918108
#  time 1542662348.6682875
#  current porosity 0.6046268295562446
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2060
#  Curr. Sph. Posn.  [0.30322217 0.95206749 0.36214644]
#  Sph. Rad. 0.037106177625960135
#  time 1542662348.860068
#  current porosity 0.6027001394977819
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2070
#  Curr. Sph. Posn.  [0.0417525  0.75476863 0.61588359]
#  Sph. Rad. 0.037113250359836356
#  time 1542662349.191839
#  current porosity 0.6007734971366656
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2080
#  Curr. Sph. Posn.  [0.49696336 0.73844258 0.88326674]
#  Sph. Rad. 0.03711174551636327
#  time 1542662349.3588326
#  current porosity 0.5988469960271501
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2090
#  Curr. Sph. Posn.  [0.43489384 0.16881672 0.98040389]
#  Sph. Rad. 0.037111187698155114
#  time 1542662349.728468
#  current porosity 0.5969206360629533
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2100
#  Curr. Sph. Posn.  [0.15962039 0.9804556  0.82035487]
#  Sph. Rad. 0.03711175129915278
#  time 1542662349.8260393
#  current porosity 0.5949941343729286
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2110
#  Curr. Sph. Posn.  [0.81583208 0.04916908 0.18777359]
#  Sph. Rad. 0.037109037488716315
#  time 1542662350.1712835
#  current porosity 0.5930674704858139
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2120
#  Curr. Sph. Posn.  [0.51099585 0.06342721 0.71329564]
#  Sph. Rad. 0.03711090042545446
#  time 1542662350.3334131
#  current porosity 0.5911407398649705
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2130
#  Curr. Sph. Posn.  [0.47758965 0.40716162 0.76092894]
#  Sph. Rad. 0.03711105553512143
#  time 1542662350.6282861
#  current porosity 0.5892140522575213
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2140
#  Curr. Sph. Posn.  [0.41024808 0.51517039 0.7088992 ]
#  Sph. Rad. 0.037114127634760824
#  time 1542662350.8886585
#  current porosity 0.5872874205803759
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2150
#  Curr. Sph. Posn.  [0.65629808 0.3251302  0.50062877]
#  Sph. Rad. 0.03710977937096474
#  time 1542662351.1418738
#  current porosity 0.5853610316889155
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2160
#  Curr. Sph. Posn.  [0.82911175 0.01226353 0.31972703]
#  Sph. Rad. 0.03710990567739542
#  time 1542662351.490343
#  current porosity 0.5834343304501081
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2170
#  Curr. Sph. Posn.  [0.90235943 0.99291393 0.54573418]
#  Sph. Rad. 0.03711101709029472
#  time 1542662351.915815
#  current porosity 0.5815077740059456
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2180
#  Curr. Sph. Posn.  [0.38207062 0.78556719 0.55598505]
#  Sph. Rad. 0.03710983528904681
#  time 1542662352.2052212
#  current porosity 0.5795813433200545
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2190
#  Curr. Sph. Posn.  [0.40705765 0.63767507 0.11515022]
#  Sph. Rad. 0.03711124447681376
#  time 1542662352.496702
#  current porosity 0.5776548245265741
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2200
#  Curr. Sph. Posn.  [0.2207153  0.1423467  0.14309682]
#  Sph. Rad. 0.037105850329391656
#  time 1542662352.7792726
#  current porosity 0.5757281935149848
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2210
#  Curr. Sph. Posn.  [0.99801323 0.89593862 0.98740748]
#  Sph. Rad. 0.037112624818580554
#  time 1542662353.126083
#  current porosity 0.5738017516065345
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2220
#  Curr. Sph. Posn.  [0.59983151 0.64734448 0.61153418]
#  Sph. Rad. 0.03711244801226606
#  time 1542662353.6272893
#  current porosity 0.5718754894675752
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2230
#  Curr. Sph. Posn.  [0.25776617 0.36086019 0.35987048]
#  Sph. Rad. 0.03710540675299078
#  time 1542662354.110381
#  current porosity 0.569948742545649
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2240
#  Curr. Sph. Posn.  [0.45176762 0.73222998 0.49774415]
#  Sph. Rad. 0.03711246276529012
#  time 1542662354.486482
#  current porosity 0.5680220269416535
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2250
#  Curr. Sph. Posn.  [0.33596727 0.06947609 0.70308842]
#  Sph. Rad. 0.0371116576751135
#  time 1542662354.8707197
#  current porosity 0.5660955463956956
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2260
#  Curr. Sph. Posn.  [0.92874244 0.99716336 0.73457884]
#  Sph. Rad. 0.03710716423491171
#  time 1542662355.2554708
#  current porosity 0.5641690812194441
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2270
#  Curr. Sph. Posn.  [0.52037758 0.97731067 0.43774977]
#  Sph. Rad. 0.037111338667480925
#  time 1542662355.7505472
#  current porosity 0.5622425853380535
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2280
#  Curr. Sph. Posn.  [0.2282556  0.6189803  0.29956796]
#  Sph. Rad. 0.03710901278884753
#  time 1542662356.03709
#  current porosity 0.5603159483418827
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2290
#  Curr. Sph. Posn.  [0.41660379 0.94364328 0.1669635 ]
#  Sph. Rad. 0.037112029930302645
#  time 1542662356.3580973
#  current porosity 0.5583893691213497
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2300
#  Curr. Sph. Posn.  [0.18050764 0.71907297 0.1052248 ]
#  Sph. Rad. 0.0371098707968381
#  time 1542662356.5846815
#  current porosity 0.5564628857276817
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2310
#  Curr. Sph. Posn.  [0.12329969 0.95474566 0.03571074]
#  Sph. Rad. 0.037110021527459486
#  time 1542662356.790595
#  current porosity 0.5545362460435843
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2320
#  Curr. Sph. Posn.  [0.91138833 0.9430536  0.47201968]
#  Sph. Rad. 0.03710750793953323
#  time 1542662357.342134
#  current porosity 0.5526098853880093
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2330
#  Curr. Sph. Posn.  [0.41132118 0.12080916 0.37975831]
#  Sph. Rad. 0.03710894976380138
#  time 1542662358.1255052
#  current porosity 0.5506832068925651
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#  Iteration 2340
#  Curr. Sph. Posn.  [0.75955889 0.08818068 0.88897688]
#  Sph. Rad. 0.037105908874978194
#  time 1542662358.5616589
#  current porosity 0.5487569366527694
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2350
#  Curr. Sph. Posn.  [0.54660749 0.55582484 0.20300323]
#  Sph. Rad. 0.037107983423912444
#  time 1542662358.846912
#  current porosity 0.546830562738515
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2360
#  Curr. Sph. Posn.  [0.26124984 0.99347438 0.6446837 ]
#  Sph. Rad. 0.037107749628553524
#  time 1542662359.2867908
#  current porosity 0.5449039849913435
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2370
#  Curr. Sph. Posn.  [0.35186905 0.48800641 0.12675978]
#  Sph. Rad. 0.03710844757095505
#  time 1542662359.7636368
#  current porosity 0.5429772839862403
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2380
#  Curr. Sph. Posn.  [0.62871668 0.31371608 0.10464182]
#  Sph. Rad. 0.03711067687364876
#  time 1542662360.2708242
#  current porosity 0.5410505504338188
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2390
#  Curr. Sph. Posn.  [0.25937051 0.58515815 0.43962181]
#  Sph. Rad. 0.03711025666727362
#  time 1542662360.5847251
#  current porosity 0.5391240910952372
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2400
#  Curr. Sph. Posn.  [0.74120515 0.67507784 0.70387299]
#  Sph. Rad. 0.03711117802889346
#  time 1542662361.0782313
#  current porosity 0.5371975193988979
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2410
#  Curr. Sph. Posn.  [0.60400281 0.7720906  0.32842304]
#  Sph. Rad. 0.03711162719982192
#  time 1542662361.880745
#  current porosity 0.535271096702369
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2420
#  Curr. Sph. Posn.  [0.76381099 0.53358082 0.59048484]
#  Sph. Rad. 0.03710953223643951
#  time 1542662362.4126995
#  current porosity 0.5333445844458955
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2430
#  Curr. Sph. Posn.  [0.32598935 0.17438155 0.78177004]
#  Sph. Rad. 0.03711042202101231
#  time 1542662363.3108954
#  current porosity 0.531417994657926
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2440
#  Curr. Sph. Posn.  [0.17001649 0.10349673 0.10653581]
#  Sph. Rad. 0.037105151384024836
#  time 1542662363.976626
#  current porosity 0.5294914033453217
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2450
#  Curr. Sph. Posn.  [0.43921107 0.82558    0.5902513 ]
#  Sph. Rad. 0.037110639494097486
#  time 1542662364.1087658
#  current porosity 0.5275648759741864
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2460
#  Curr. Sph. Posn.  [0.44701896 0.09674874 0.62071347]
#  Sph. Rad. 0.0371082424224897
#  time 1542662364.9233892
#  current porosity 0.5256383739895154
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2470
#  Curr. Sph. Posn.  [0.98845197 0.94691146 0.71225142]
#  Sph. Rad. 0.03711046194581697
#  time 1542662365.3994384
#  current porosity 0.5237120145667479
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2480
#  Curr. Sph. Posn.  [0.4084423  0.27313124 0.95002678]
#  Sph. Rad. 0.037109491000778067
#  time 1542662365.666781
#  current porosity 0.5217855661021524
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2490
#  Curr. Sph. Posn.  [0.14024653 0.98988223 0.13078746]
#  Sph. Rad. 0.03710626428181612
#  time 1542662366.6062655
#  current porosity 0.5198590733253782
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2500
#  Curr. Sph. Posn.  [0.21521237 0.40860405 0.11973326]
#  Sph. Rad. 0.03711213322730382
#  time 1542662367.376959
#  current porosity 0.5179325656156499
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2510
#  Curr. Sph. Posn.  [0.97576021 0.55709006 0.78268997]
#  Sph. Rad. 0.0371059541877826
#  time 1542662368.1310284
#  current porosity 0.516006084692127
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2520
#  Curr. Sph. Posn.  [0.18267608 0.88771853 0.79395382]
#  Sph. Rad. 0.03710829132863189
#  time 1542662368.4994075
#  current porosity 0.5140797770007615
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2530
#  Curr. Sph. Posn.  [0.92510877 0.88418397 0.90120883]
#  Sph. Rad. 0.03710752659279899
#  time 1542662368.9209273
#  current porosity 0.5121532278519674
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2540
#  Curr. Sph. Posn.  [0.35008627 0.70847721 0.69155634]
#  Sph. Rad. 0.03711159855290526
#  time 1542662369.3498614
#  current porosity 0.5102267015111392
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2550
#  Curr. Sph. Posn.  [0.51148883 0.94079873 0.06192467]
#  Sph. Rad. 0.03710581178594117
#  time 1542662369.8288484
#  current porosity 0.5082998639707814
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1
#
#  Iteration 2560
#  Curr. Sph. Posn.  [0.6956519  0.63288769 0.08403687]
#  Sph. Rad. 0.037113421244878965
#  time 1542662370.60664
#  current porosity 0.5063734588622945
#  bbox_vertices [(0, 0, 0), (1, 1, 1)]
#  domain_volume 1

# %%
import numpy as np

idx,x,y,z,r = np.loadtxt("packing.txt",delimiter=",",skiprows=1,unpack=True)

# Check Porosity
volume = 0.
for i in range(0,len(idx)):
	volume = volume + 4./3.*np.pi*r[i]*r[i]*r[i]
print("check porosity " , 1.-volume)


# # Check Distribution Parameters
# print(np.mean(r))
# print(np.std(r))

#Check Overlap
import sklearn.metrics 
from sklearn.metrics import pairwise_distances as pwdist
pts = np.vstack((x,y,z)).T
dist=pwdist(pts)
row,col=np.where(dist<r[:,None]+r[None,:])
[dist[ri,ci] for ri,ci in zip(row,col) if ri<ci]

    
print("Total Number of Overlaps ", count-1)
# Out:
# check porosity  0.414594343819192
# Total Number of Overlaps  0

# %%
np.where(pts>1)
# Out:
# (array([   7,   11,   11, ..., 2880, 2881, 2881]),
#  array([0, 0, 1, ..., 2, 0, 1]))

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


psize = ((pvolumes-pvolumes.min()))
psize = psize/psize.max()
psize = psize * nsamples

fig = plt.figure(figsize=(16,16))
ax = fig.add_subplot(111, projection='3d')
xs,ys,zs=pts[:,0],pts[:,1],pts[:,2]
ax.scatter(xs, ys, zs,s=psize,c=psize,alpha=0.6)
plt.show()

# %%
# # Check Porosity
# volume = 0.
# for i in range(0,len(idx)):seed=0
# xmax,xmin=1,0
# ymax,ymin=1,0
# zmax,zmin=1,0
# ndimensions=3
# radii_dist='lognormal'
# radius_mu=1.
# radius_sig2=0.25
# tol_self_collision=1e-2
# increment_print=int(1e2)
# nsamples=int(1e3 * 2) #expect: far fewer used (until we achieve target porosity within tolerance)

# percentilemin,percentilemax=5,95

# target_porosity=0.4
# volume = volume + 4./3.*np.pi*r[i]*r[i]*r[i]
# print(1.-volume)


# # Check Distribution Parameters
# print(np.mean(r))
# print(np.std(r))


# #Check Overlap
# count = 0 
# for i in range(0,len(idx)):
#     add_to_count=0;
#     for j in range(i+1,len(idx)):
#         distance = np.sqrt( (x[i]-x[j])*(x[i]-x[j]) + (y[i]-y[j])*(y[i]-y[j]) + (z[i]-z[j])*(z[i]-z[j]) )
#         if (distance < (r[i]+r[j])):
#             add_to_count=1
#     count  = count + add_to_count; 
    
# print("Total Number of Overlaps ", count-1)
# Out:
# 0.6395003928365999
# 0.039079617732316226
# 2.520015972677124e-06
# Total Number of Overlaps  812
# 0.9997500838979378
# 0.039079617732316226
# 2.520015972677124e-06
# Total Number of Overlaps  812

# %%
psize = ((pvolumes-pvolumes.min()))
psize = psize/psize.max()
psize = psize * nsamples



fig = plt.figure(figsize=(16,16))
ax = fig.add_subplot(111, projection='3d')
X,Y,Z = pts[:,0],pts[:,1],pts[:,2]
cube = ax.scatter(X, Y, Z, zdir='z', s=psize, c=psize,alpha=0.4)
cbar = fig.colorbar(cube, shrink=0.6, aspect=5)
plt.savefig(save_filename+'_3d.png',dpi=200)
# plt.show()



# len(),nsamples
plt.figure(figsize=(16,16))
plt.scatter(pts[:,0],pts[:,1],s=psize,c=psize,alpha=0.6)
plt.colorbar()
plt.savefig(save_filename+'_.png',dpi=200)
